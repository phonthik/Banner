# %% [markdown]
# # Python Data Visualization (Matplotlib)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Figures and Axes

# %%
# subplots() returns a figure and axis

# Matplotlib graphs your data on Figures (e.g., windows, Jupyter widgets, etc.), each of which can contain one or more axes.
# Axes is an area where points can be specified in terms of x-y coordinates.

# The simplest way of creating a Figure with an Axes is using subplots. 
# We can then use Axes.plot to draw some data on the Axes:



fig, ax = plt.subplots()   # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [4, 3, 2, 1])  # Plot some data on the axes(x, y).

# %% [markdown]
# # Line Plot

# %%
# np.linspace?
# start : array_like
#     The starting value of the sequence.
# stop : array_like
#     The end value of the sequence, unless `endpoint` is set to False.
#     In that case, the sequence consists of all but the last of ``num + 1``
#     evenly spaced samples, so that `stop` is excluded.  Note that the step
#     size changes when `endpoint` is False.
# num : int, optional
#     Number of samples to generate. Default is 50. Must be non-negative.
# endpoint : bool, optional
    
x = np.linspace(0, 100, 5) # give me spaced data


y1 = np.random.randint(1, 5, 5) # give me random data from 1 to 10

fig, ax = plt.subplots()

ax.plot(x, y1) 

plt.show()

# %%
x
# Out:
# array([  0.,  25.,  50.,  75., 100.])

# %%
y1
# Out:
# array([1, 4, 2, 4, 1])

# %% [markdown]
# ## Create multiple plots

# %%
# Render plots in separate axes;   subplots(n_rows, n_cols)
y2 = np.random.randint(1, 11, 5)

fig, axes = plt.subplots(3) # 2 rows

axes[0].plot(x, y1)
axes[1].plot(x, y2)

plt.show()

# %% [markdown]
# ## Set the figsize

# %%
# Set the size of the figure  (figsize=(w, h))
fig, axes = plt.subplots(1,2, figsize=(20, 10)) # one row, 2 columns


axes[0].plot(x, y1)
axes[1].plot(x, y2)

plt.show()

# %% [markdown]
# ## Set properties

# %%
fig, ax = plt.subplots()
ax.plot(x, y1)

# more flexible way of setting properties
ax.set_title("Set Title Plot")
ax.set_ylabel("Y Label")
ax.set_xlabel("X Label")

plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x, y2)

# more convenient way of setting properties
ax.set(title="set Title Plot", ylabel="Y Label", xlabel="X Label")

plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# ### Dataset: Diabetes_cleaned

# %%
df = pd.read_csv(r"C:\Users\venKPhonthipsavath\OneDrive - Banner Health\Python training\Lesson 4\dataset\diabetes\diabetes_cleaned.csv")
df.head()
# Out:
#      Id  Pregnancies  Glucose  SkinThickness  Insulin   BMI  \
# 0   446            0    180.0           63.0     14.0  59.4
# 1  1214            0    180.0           63.0     14.0  59.4
# 2  1684            0    180.0           63.0     14.0  59.4
# 3  2273            0    180.0           63.0     14.0  59.4
# 4   229            4    197.0           39.0    744.0  36.7
#
#    DiabetesPedigreeFunction  Age Age_group  Outcome  BloodPressure_num
# 0                     2.420   25     20-40        1                 78
# 1                     2.420   25     20-40        1                 78
# 2                     2.420   25     20-40        1                 78
# 3                     2.420   25     20-40        1                 78
# 4                     2.329   31     20-40        0                 70

# %%
df.describe()
# Out:
#                 Id  Pregnancies      Glucose  SkinThickness      Insulin  \
# count  2768.000000  2768.000000  2768.000000    2768.000000  2768.000000
# mean   1384.500000     3.742775   121.863439      29.205925   140.669798
# std     799.197097     3.323801    30.503499       9.032220    82.887979
# min       1.000000     0.000000    44.000000       7.000000    14.000000
# 25%     692.750000     1.000000    99.000000      25.000000   120.000000
# 50%    1384.500000     3.000000   117.000000      29.000000   126.000000
# 75%    2076.250000     6.000000   141.000000      32.000000   130.000000
# max    2768.000000    17.000000   199.000000     110.000000   846.000000
#
#               BMI  DiabetesPedigreeFunction          Age      Outcome  \
# count  2768.00000               2768.000000  2768.000000  2768.000000
# mean     32.59375                  0.471193    33.124639     0.343931
# std       7.10119                  0.325669    11.773123     0.475104
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2768 non-null   int64
#  1   Pregnancies               2768 non-null   int64
#  2   Glucose                   2768 non-null   float64
#  3   SkinThickness             2768 non-null   float64
#  4   Insulin                   2768 non-null   float64
#  5   BMI                       2768 non-null   float64
#  6   DiabetesPedigreeFunction  2768 non-null   float64
#  7   Age                       2768 non-null   int64
#  8   Age_group                 2768 non-null   object
#  9   Outcome                   2768 non-null   int64
#  10  BloodPressure_num         2768 non-null   int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 238.0+ KB

# %%
fig, ax = plt.subplots()
ax.hist(df['Age'], color='b', edgecolor='black')
ax.set(xlabel="Age", title="Histogram")

"""
The basic built-in colors:
b: blue
g: green
r: red
c: cyan
m: magenta
y: yellow
k: black
w: white
"""

plt.show()

# %% [markdown]
# ### Set the number of bins to display

# %%
fig, ax = plt.subplots()
ax.hist(df['Age'], color = 'b', edgecolor='black', bins = 25)
ax.set(xlabel="Age", title="Histogram")
plt.show()

# %% [markdown]
# ### Set a custom color ****** LINK TO SET COLORS
# https://htmlcolorcodes.com

# %%
fig, ax = plt.subplots()
ax.hist(df['BloodPressure_num'], color = '#FF336B', edgecolor='black') # HEX colors
ax.set(xlabel="Blood Pressure Num", title="Histogram")
plt.show()

# %% [markdown]
# # Bar Plot

# %%
between = df.loc[(df["BMI"]>15) & (df["BMI"]<20), "BMI"].count()
between
# Out:
# 42

# %%
fig, ax = plt.subplots()

# Determine the quantity/count of a feature
less_than = df.loc[df["BMI"]<=18.5, "BMI"].count()
between = df.loc[(df["BMI"]>18.5) & (df["BMI"]<25), "BMI"].count()
greater_than = df.loc[df["BMI"]>25, "BMI"].count()


# Plot the respective quantities
#  (x-coord for bars)

#bar([x, height, width], height)
ax.bar([0,1,2], height=[less_than, between, greater_than], edgecolor='black', align='center', alpha=.5)
plt.xticks([0,1,2], ["<=18.5", ">18.5 & <25", ">25"])

ax.set_title("BMI")

plt.show()

# %% [markdown]
# # Scatter Plot

# %%
df['Age'][:100]
# Out:
# 0     25
# 1     25
# 2     25
# 3     25
# 4     31
#       ..
# 95    49
# 96    49
# 97    39
# 98    39
# 99    39
# Name: Age, Length: 100, dtype: int64

# %%
df['BMI'][:200]
# Out:
# 0      59.4
# 1      59.4
# 2      59.4
# 3      59.4
# 4      36.7
#        ...
# 195    30.4
# 196    30.4
# 197    30.4
# 198    36.4
# 199    36.4
# Name: BMI, Length: 200, dtype: float64

# %%
fig, ax = plt.subplots()
plt.style.use('seaborn-whitegrid')

#               (x-axis (first 200 elements, y-axis, alpha(shading), size, color)
ax.scatter(x=df['Age'][:200], y=df['BMI'][:200], alpha=.3, s = 100, c = "green")
 
# Set the properties
ax.set(title="Diabetes Data", xlabel='Age', ylabel="BMI")

plt.show()

# %% [markdown]
# ## Set custom tick/grid parameters

# %%
plt.style?

# %%
from matplotlib import style   
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
fig, ax = plt.subplots()
plt.style.use('_classic_test_patch')

ax.scatter(x=df['Age'][:300], y=df['BMI'][:300], alpha=.3,s = 100, c = "black")
 
# Set the properties
ax.set(title="BMI Data", xlabel='Age', ylabel="BMI")

# Set custome tick/grid parameters
ax.tick_params(labelcolor="blue", labelsize=16)

# %% [markdown]
# ### Auto-setting the colors based on the class (target) membership
# The target variable must be an integer.

# %%
print(df['Outcome'].head(100))
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     0
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: Outcome, Length: 100, dtype: int64

# %%
df['Outcome_cat'] = pd.Categorical(df['Outcome'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        2768 non-null   int64
#  1   Pregnancies               2768 non-null   int64
#  2   Glucose                   2768 non-null   float64
#  3   SkinThickness             2768 non-null   float64
#  4   Insulin                   2768 non-null   float64
#  5   BMI                       2768 non-null   float64
#  6   DiabetesPedigreeFunction  2768 non-null   float64
#  7   Age                       2768 non-null   int64
#  8   Age_group                 2768 non-null   object
#  9   Outcome                   2768 non-null   int64
#  10  BloodPressure_num         2768 non-null   int64
#  11  Outcome_cat               2768 non-null   category
# dtypes: category(1), float64(5), int64(5), object(1)
# memory usage: 240.8+ KB

# %%
import matplotlib.colors as colors
import matplotlib.cm as cmx

# Get unique names of species
uniq = list(set(df['Outcome_cat']))
uniq

# Set the color map to match the number of species
z = range(1,len(uniq))
hot = plt.get_cmap('hot')
cNorm  = colors.Normalize(vmin=0, vmax=len(uniq))
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=hot)

# %%
fig, ax = plt.subplots()

sc = ax.scatter(df['Age'][:200], df['BMI'][:200], alpha=.3,
          s = 200, c = df["Outcome_cat"][:200],  cmap='inferno')

ax.set(title="Diabetes Data", xlabel='Age', ylabel='BMI')

plt.show()

# %%
import matplotlib.patches

levels, categories = pd.factorize(df['Outcome_cat'][:200])
colors = [plt.cm.tab10(i) for i in levels] # using the "tab10" colormap
handles = [matplotlib.patches.Patch(color=plt.cm.tab10(i), label=c) for i, c in enumerate(categories)]

plt.scatter(df['Age'][:200], df['BMI'][:200], c = colors)
plt.gca().set(title="Diabetes Data", xlabel='Age', ylabel='BMI')
plt.legend(handles=handles, title='Outcome')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Set the marker (shape)

# %%
fig, ax = plt.subplots()

# sample markers: "o"(default), v", "^", x", "P", "d", "."
plt.scatter(df['Age'][:200], df['BMI'][:200], s = 100, alpha=.2, marker="x", c = colors)
plt.gca().set(title="Diabetes Data", xlabel='Age', ylabel='BMI')
plt.legend(handles=handles, title='Outcome')
plt.show

plt.show()

# %% [markdown]
# # Python Data Visualization (Pandas, Seaborn)

# %% [markdown]
# # Pandas
# You can set many of the plot's parameters within the plot method.

# %% [markdown]
# ### Pandas Box Plot

# %%
data = pd.DataFrame(df,columns=['DiabetesPedigreeFunction', 'Age_group'])

data.boxplot(column='DiabetesPedigreeFunction', by='Age_group', figsize=(15,5))

plt.title('Diabetes Pedigree Function')
# Out:
# Text(0.5, 1.0, 'Diabetes Pedigree Function')

# %%
dataPivot = data.pivot(columns='Age_group', values='DiabetesPedigreeFunction')
# dataPivot = dataPivot.fillna(0)
dataPivot.tail(600)
# dt = dataPivot.dropna().values
# dt.tail(600)
# Out:
# Age_group  20-40  41-60  61-80  >80
# 2168         NaN  0.233    NaN  NaN
# 2169         NaN  0.233    NaN  NaN
# 2170         NaN  0.232    NaN  NaN
# 2171       0.231    NaN    NaN  NaN
# 2172       0.231    NaN    NaN  NaN
# ...          ...    ...    ...  ...
# 2763       0.084    NaN    NaN  NaN
# 2764       0.084    NaN    NaN  NaN
# 2765       0.078    NaN    NaN  NaN
# 2766       0.078    NaN    NaN  NaN
# 2767       0.078    NaN    NaN  NaN
#
# [600 rows x 4 columns]

# %%
data20 = pd.DataFrame(dataPivot['20-40']).dropna().values
data40 = pd.DataFrame(dataPivot['41-60']).dropna().values
data60 = pd.DataFrame(dataPivot['61-80']).dropna().values
data80 = pd.DataFrame(dataPivot['>80']).dropna().values

print(pd.DataFrame(dataPivot['20-40']))
# Out:
#       20-40
# 0     2.420
# 1     2.420
# 2     2.420
# 3     2.420
# 4     2.329
# ...     ...
# 2763  0.084
# 2764  0.084
# 2765  0.078
# 2766  0.078
# 2767  0.078
#
# [2768 rows x 1 columns]

# %%
print(pd.DataFrame(dataPivot['20-40']).dropna().values)
# Out:
# [[2.42 ]
#  [2.42 ]
#  [2.42 ]
#  ...
#  [0.078]
#  [0.078]
#  [0.078]]

# %%
plt.boxplot(data80)
plt.show()

# %%
plt.boxplot(data20)
plt.show()

# %%
df.head()
# Out:
#      Id  Pregnancies  Glucose  SkinThickness  Insulin   BMI  \
# 0   446            0    180.0           63.0     14.0  59.4
# 1  1214            0    180.0           63.0     14.0  59.4
# 2  1684            0    180.0           63.0     14.0  59.4
# 3  2273            0    180.0           63.0     14.0  59.4
# 4   229            4    197.0           39.0    744.0  36.7
#
#    DiabetesPedigreeFunction  Age Age_group  Outcome  BloodPressure_num  \
# 0                     2.420   25     20-40        1                 78
# 1                     2.420   25     20-40        1                 78
# 2                     2.420   25     20-40        1                 78
# 3                     2.420   25     20-40        1                 78
# 4                     2.329   31     20-40        0                 70
#
#   Outcome_cat
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0

# %%
df["Age"][:10] # Print the first 25 rows
# Out:
# 0    25
# 1    25
# 2    25
# 3    25
# 4    31
# 5    31
# 6    31
# 7    33
# 8    25
# 9    25
# Name: Age, dtype: int64

# %%
# Series is one column !!!!!!!

df["Age"][:10].plot(kind="line", figsize=(10,5), title="Pandas Line Plot")
# Out:
# <AxesSubplot:title={'center':'Pandas Line Plot'}>

# %% [markdown]
# ### Multiple line plots

# %%
df[["BloodPressure_num", "Age"]][:25].plot(kind="line", 
             figsize=(10,5), title="Pandas Line Plot")
# Out:
# <AxesSubplot:title={'center':'Pandas Line Plot'}>

# %%
# Multiple lines

df[:100].plot(kind="line", y=["BloodPressure_num", "Insulin", "SkinThickness"], 
             figsize=(10,5), title="Pandas Line Plot")
# Out:
# <AxesSubplot:title={'center':'Pandas Line Plot'}>

# %%
# Using different styles

# df.plot?
df[:100].plot(kind="line", y=["BloodPressure_num", "Insulin", "SkinThickness"], 
              style=['b-o', 'r-s', 'k-p'], # 'k:', 'g-.'  first give color then style, 
             figsize=(20,5), title="Pandas Line Plot")
# Out:
# <AxesSubplot:title={'center':'Pandas Line Plot'}>

# %% [markdown]
# ### Marker Description
# 'o'	Circle
# '*'	Star
# '.'	Point
# ','	Pixel
# 'x'	X
# 'X'	X (filled)
# '+'	Plus
# 'P'	Plus (filled)
# 's'	Square
# 'D'	Diamond
# 'd'	Diamond (thin)
# 'p'	Pentagon
# 'H'	Hexagon
# 'h'	Hexagon
# 'v'	Triangle Down
# '^'	Triangle Up
# '<'	Triangle Left
# '>'	Triangle Right
# '1'	Tri Down
# '2'	Tri Up
# '3'	Tri Left
# '4'	Tri Right
# '|'	Vline
# '_'	Hline

# %% [markdown]
# ## Single character Colors
# 'b' as blue
# 'g' as green
# 'r' as red
# 'c' as cyan
# 'm' as magenta
# 'y' as yellow
# 'k' as black
# 'w' as white

# %% [markdown]
# ### Define subplots to render plots in separate axes.

# %%
# df.plot?
# subplots : bool, default False
#     Make separate subplots for each column.

df[:10].plot(kind="line", y=["BloodPressure_num", "Insulin", "SkinThickness"], 
              style=['b-o', 'r-s', 'k-p'], # 'k:', 'g-.'  first give color then style, 
             figsize=(20,5), title="Pandas Line Plot",
             subplots=True, layout=(3,1)) # OR SIDE BY SIDE (1,3)

# Set the title of the whole figure
plt.suptitle("Diabetes sub plots of Line Plots")
plt.show()

# %% [markdown]
# # Histogram

# %%
# set legend=True to display a legend

# df.plot.hist?
# Signature: df.plot.hist(by=None, bins=10, **kwargs)
# Docstring:
# Draw one histogram of the DataFrame's columns.

# A histogram is a representation of the distribution of data.
# This function groups the values of all given Series in the DataFrame
# into bins and draws all bins in one :class:`matplotlib.axes.Axes`.
# This is useful when the DataFrame's Series are in a similar scale.

df["Age"].plot(kind="hist", color="b", edgecolor='black', title="Age Histogram", figsize=(20,5), legend=True, bins=10)
plt.show()

# %%
# Call plot from the dataframe
# df.plot?


# see the difference in passing Age to the y axis
df.plot(y="Age", kind="hist", color="y", 
        edgecolor='black', linewidth=2.2, title="Age Histogram", figsize=(20, 5), legend=True)
plt.show()

# %% [markdown]
# ## Bar Plot

# %% [markdown]
# ### Call the docstring to see the different types of plots
#
# df.plot?
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot.

# %% [markdown]
# ### Using plots within dataframe methods

# %%
# Looks at the first 200 values
df[:200]["Age_group"].value_counts()
# Out:
# 20-40    139
# 41-60     60
# >80        1
# Name: Age_group, dtype: int64

# %%
# Use dataframe loc to see value counts that are not in the age group >80
df.loc[(df["Age_group"] != ">80"), "Age_group"].value_counts()
# Out:
# 20-40    2083
# 41-60     578
# 61-80     102
# Name: Age_group, dtype: int64

# %%
df[:200].loc[(df["Age_group"] != ">80"), "Age_group"].value_counts()
# Out:
# 20-40    139
# 41-60     60
# Name: Age_group, dtype: int64

# %%
df["Age_group"].value_counts().plot(kind="bar", title="Age group")
# Out:
# <AxesSubplot:title={'center':'Age group'}>

# %%
df[:200].loc[(df["Age_group"] != ">80"), "Age_group"].value_counts().plot(
    kind='bar', title="First 200 values for Age group")
# Out:
# <AxesSubplot:title={'center':'First 200 values for Age group'}>

# %%
df.loc[(df["Age_group"] != ">80"), "Age_group"].value_counts().plot(
    kind='bar', edgecolor='black', title="First 200 values for Age group")
# Out:
# <AxesSubplot:title={'center':'First 200 values for Age group'}>

# %%
# Plot the whole Age group
df["Age_group"].value_counts().plot(
    kind='bar', edgecolor='black', title="Whole Age group", rot="horizontal", fontsize=16)
# Out:
# <AxesSubplot:title={'center':'Whole Age group'}>

# %% [markdown]
# ## Horizontal bar plot with increased fontsize and with horizontal ticks

# %%
df["Age_group"].value_counts().plot(
    kind='barh', edgecolor='black', title="All values for Age group", rot="horizontal", fontsize=16)
# Out:
# <AxesSubplot:title={'center':'All values for Age group'}>

# %% [markdown]
# ## Scatter Plot

# %%
df.head()
# Out:
#      Id  Pregnancies  Glucose  SkinThickness  Insulin   BMI  \
# 0   446            0    180.0           63.0     14.0  59.4
# 1  1214            0    180.0           63.0     14.0  59.4
# 2  1684            0    180.0           63.0     14.0  59.4
# 3  2273            0    180.0           63.0     14.0  59.4
# 4   229            4    197.0           39.0    744.0  36.7
#
#    DiabetesPedigreeFunction  Age Age_group  Outcome  BloodPressure_num  \
# 0                     2.420   25     20-40        1                 78
# 1                     2.420   25     20-40        1                 78
# 2                     2.420   25     20-40        1                 78
# 3                     2.420   25     20-40        1                 78
# 4                     2.329   31     20-40        0                 70
#
#   Outcome_cat
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0

# %% [markdown]
# df.plot?
# s : scalar or array_like, shape (n, ), optional
# size in points^2. Default is rcParams['lines.markersize'] ** 2.
#
# marker : MarkerStyle, optional, default: ‘o’
# See markers for more information on the different styles of markers scatter supports.
# marker can be either an instance of the class or the text shorthand for a particular marker.
#
# alpha : scalar, optional, default: None
# The alpha blending value, between 0 (transparent) and 1 (opaque)

# %%
df[:200].plot(kind='scatter', x='Age', y='BMI',s=400, marker='p', alpha=.3, figsize=(20,8), 
              title="First 200 values for Age by BMI")
plt.show()

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %% [markdown]
# ## Lineplot
#
# ### Series
# Set the "data" parameter equal to the variable to be used for the y-axis. It uses the row index for the x-axis.

# %%
sns.lineplot(data=df["Age"][:50])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
df.head()
# Out:
#      Id  Pregnancies  Glucose  SkinThickness  Insulin   BMI  \
# 0   446            0    180.0           63.0     14.0  59.4
# 1  1214            0    180.0           63.0     14.0  59.4
# 2  1684            0    180.0           63.0     14.0  59.4
# 3  2273            0    180.0           63.0     14.0  59.4
# 4   229            4    197.0           39.0    744.0  36.7
#
#    DiabetesPedigreeFunction  Age Age_group  Outcome  BloodPressure_num  \
# 0                     2.420   25     20-40        1                 78
# 1                     2.420   25     20-40        1                 78
# 2                     2.420   25     20-40        1                 78
# 3                     2.420   25     20-40        1                 78
# 4                     2.329   31     20-40        0                 70
#
#   Outcome_cat
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0

# %%
# styledict, or one of {darkgrid, whitegrid, dark, white, ticks}
# A dictionary of parameters or the name of a preconfigured style.

sns.set_style("ticks")

# %% [markdown]
# The line plot aggregates over multiple y values at each value of x and shows an estimate of the mean and a 95% confidence interval for that estimate.

# %%
sns.lineplot(data=df, x="SkinThickness", y="Age")

plt.show()

# %%
# ## Style by categorical feature

sns.lineplot(data=df, x="SkinThickness", y="Age", hue="Outcome", style="Outcome")
plt.show()

# %%
sns.relplot?

# %%
# Relation Plot
# Allows line plot grouping within an additional categorical variable.

sns.relplot(
    data=df, x="SkinThickness", y="Age", hue="Outcome", style="Outcome",
    col="Age_group", kind="line", height=5
)
plt.show()

# %% [markdown]
# # Setting styles

# %%
# darkgrid (default), 
# whitegrid, 
# dark, 
# white, 
# ticks

sns.set_style("darkgrid")

# %% [markdown]
# ## Scale plot elements by setting the context
# There are four preset contexts in order of relative size: paper, notebook, talk, poster.

# %%
# This method is used to set the parameters that control the scaling of plot elements. 
# By using this the general style is unaffected, although it does influence things like the size of the labels, 
# lines, and other plot points.

sns.set_context("talk")

# %%
sns.lineplot(data=df, x="SkinThickness", y="Age", hue="Outcome", style="Outcome")
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Age'>

# %% [markdown]
# ## Set colors by selecting a desired palette (color map)
# https://matplotlib.org/stable/gallery/color/colormap_reference.html
#
# Sample colormaps: Set1, Dark2, Accent, Pastel1, Reds, Greens, Blues

# %%
sns.set_palette("Pastel1")

# %%
sns.lineplot(data=df, x="SkinThickness", y="Age", hue="Outcome", style="Outcome")
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Age'>

# %% [markdown]
# ## Setting the theme enables customizing the style, context and colors together

# %%
sns.set_theme(style='white', context='talk', palette='Set1')

# %%
sns.lineplot(data=df, x="SkinThickness", y="Age", hue="Outcome", style="Outcome")
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Age'>

# %% [markdown]
# ## Reset all to the Seaborn defaults

# %%
sns.set_theme() # defaults: style='darkgrid', context='notebook', palette='tab10'

sns.lineplot(data=df, x="SkinThickness", y="Age", hue="Outcome", style="Outcome")
# Out:
# <AxesSubplot:xlabel='SkinThickness', ylabel='Age'>

# %% [markdown]
# # Seaborn Box Plot

# %%
# darkgrid (default), 
# whitegrid, 
# dark, 
# white, 
# ticks

sns.set_style("whitegrid")
sns.boxplot(data=df["Age"], palette="deep")

# Set titles and labels
plt.suptitle("Box Plot")
plt.ylabel('Age')
plt.xticks([0], ['Diabetes Dataset'])
# Out:
# ([<matplotlib.axis.XTick at 0x1df327943d0>], [Text(0, 0, 'Diabetes Dataset')])

# %% [markdown]
# # Density Plot

# %%
df.head()
# Out:
#      Id  Pregnancies  Glucose  SkinThickness  Insulin   BMI  \
# 0   446            0    180.0           63.0     14.0  59.4
# 1  1214            0    180.0           63.0     14.0  59.4
# 2  1684            0    180.0           63.0     14.0  59.4
# 3  2273            0    180.0           63.0     14.0  59.4
# 4   229            4    197.0           39.0    744.0  36.7
#
#    DiabetesPedigreeFunction  Age Age_group  Outcome  BloodPressure_num  \
# 0                     2.420   25     20-40        1                 78
# 1                     2.420   25     20-40        1                 78
# 2                     2.420   25     20-40        1                 78
# 3                     2.420   25     20-40        1                 78
# 4                     2.329   31     20-40        0                 70
#
#   Outcome_cat
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0

# %% [markdown]
# ## Age group between 20-40 by Insulin and Outcome

# %%
df.loc[df["Age_group"] == "20-40", "Insulin"]
# Out:
# 0        14.0
# 1        14.0
# 2        14.0
# 3        14.0
# 4       744.0
#         ...
# 2763    126.0
# 2764    126.0
# 2765    126.0
# 2766    126.0
# 2767    126.0
# Name: Insulin, Length: 2083, dtype: float64

# %%
fig, ax = plt.subplots()
ax.set(title="Age group between 20-40 insulin variance by outcome")

sns.kdeplot(data=df, x=df.loc[df["Age_group"] == "20-40", "Insulin"],
                 hue = "Outcome", fill=True, ax=ax)


plt.show()

# %%
df["Age_group"].unique()
# Out:
# array(['20-40', '41-60', '>80', '61-80'], dtype=object)

# %%
fig, ax = plt.subplots()
ax.set(title="Age group between 41-60 insulin variance by outcome")

sns.kdeplot(data=df, x=df.loc[df["Age_group"] == "41-60", "Insulin"],
                 hue = "Outcome", fill=True, ax=ax)


plt.show()

# %% [markdown]
# ### Combine the plots and scale

# %%
fig, ax = plt.subplots(1,2, figsize=(13, 5))
ax[0].set(title="Age group between 20-40 insulin variance by outcome")
ax[1].set(title="Age group between 41-60 insulin variance by outcome")

sns.kdeplot(data=df, x=df.loc[df["Age_group"] == "20-40", "Insulin"],
                 hue = "Outcome", fill=True, ax=ax[0])

sns.kdeplot(data=df, x=df.loc[df["Age_group"] == "41-60", "Insulin"],
                 hue = "Outcome", fill=True, ax=ax[1])
# Out:
# <AxesSubplot:title={'center':'Age group between 41-60 insulin variance by outcome'}, xlabel='Insulin', ylabel='Density'>
